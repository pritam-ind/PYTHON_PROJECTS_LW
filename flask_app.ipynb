# %%
# FLASK APP

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/")
def home():
    # Returning the entire Portfolio HTML as a string
    # html , css code taken form open ai just to check whether my flask app running or not........success!
    return """
    <!DOCTYPE html>
    <html lang="en">
    <head>
        <title>Pritam Portfolio</title>
        <style>
            body { font-family: sans-serif; margin: 0; padding: 0; background: #f4f4f4; color: #333; }
            header { background: #000; color: #fff; padding: 20px; text-align: center; }
            nav { background: #333; overflow: hidden; display: flex; justify-content: center; }
            nav a { color: white; padding: 14px 20px; text-decoration: none; }
            nav a:hover { background-color: #ddd; color: black; }
            .container { max-width: 800px; margin: 20px auto; background: white; padding: 20px; box-shadow: 0 0 10px rgba(0,0,0,0.1); }
            .section { display: none; } /* Hidden by default */
            .section.active { display: block; } /* Visible when active */
            h1, h2 { border-bottom: 2px solid #333; padding-bottom: 10px; }
            .skill-tag { background: #eee; padding: 5px 10px; border-radius: 5px; margin-right: 5px; display: inline-block; }
        </style>
    </head>
    <body>

        <header>
            <h1>Pritam's Portfolio</h1>
            <p>B.Tech AI/ML | Python Developer | Linux Enthusiast</p>
        </header>

        <nav>
            <a href="#" onclick="showSection('home')">Home</a>
            <a href="#" onclick="showSection('resume')">Resume</a>
            <a href="#" onclick="showSection('projects')">Projects</a>
            <a href="#" onclick="showSection('contact')">Contact</a>
        </nav>

        <div class="container">
            <div id="home" class="section active">
                <h2>Welcome</h2>
                <p>Hello! I am a passionate AI/ML student currently interning at LinuxWorld. 
                This website is powered by <strong>Python Flask</strong> backend.</p>
                <p>I am learning to bridge the gap between Networking concepts and Web Development.</p>
            </div>

            <div id="resume" class="section">
                <h2>Resume</h2>
                <h3>Education</h3>
                <p><strong>B.Tech in AI & ML</strong> - Vivekananda Global University (2025)</p>
                
                <h3>Technical Skills</h3>
                <p>
                    <span class="skill-tag">Python</span>
                    <span class="skill-tag">Flask</span>
                    <span class="skill-tag">Linux (RHEL)</span>
                    <span class="skill-tag">Data Structures</span>
                    <span class="skill-tag">Networking</span>
                </p>

                <h3>Experience</h3>
                <p><strong>Intern Trainee</strong> at LinuxWorld Informatics Pvt Ltd</p>
                <ul>
                    <li>Building AI-integrated web applications.</li>
                    <li>Mastering Python automation and Linux Administration.</li>
                </ul>
            </div>

            <div id="projects" class="section">
                <h2>Projects</h2>
                <ul>
                    <li><strong>Jarvis Voice Assistant:</strong> A Python automation tool using SpeechRecognition.</li>
                    <li><strong>Hostel Management System:</strong> A CLI-based management tool using Python logic.</li>
                    <li><strong>Flask Portfolio:</strong> This dynamic website serving HTML via Python.</li>
                </ul>
            </div>

            <div id="contact" class="section">
                <h2>Contact Me</h2>
                <p><strong>Location:</strong> Jaipur, Rajasthan</p>
                <p><strong>Email:</strong> myselfpritam1@gmail.com</p>
                <p><strong>LinkedIn:</strong> www.linkedin.com/in/pritam-ind</p>
                <p><strong>GitHub:</strong> https://github.com/pritam-ind</p>
            </div>
        </div>

        <script>
            // Simple JS to switch tabs without reloading
            function showSection(id) {
                // Hide all sections
                document.querySelectorAll('.section').forEach(div => div.classList.remove('active'));
                // Show the clicked section
                document.getElementById(id).classList.add('active');
            }
        </script>

    </body>
    </html>
    """

if __name__ == "__main__":
    app.run(debug=True)
