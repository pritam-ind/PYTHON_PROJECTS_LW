# %%
import time
balance = 5000
attempts = 3

while attempts > 0:
    print("Welcome to MY BANK OF INDIA\nATM Service Available 24x7\nInsert your card to proceed\n")
    pin = input("Enter the ATM PIN here: ")
    if pin == "1111":
        print("PIN Verified")
        withdraw = int(input("Enter the amount you want to withdraw: "))

        if withdraw <= balance:
            print("Processing your payment.....................")
            time.sleep(2)
            print("\nTransaction Successfule.\nPlease collect your payment!")
            balance -= withdraw
            print(f"Left balance in account : {balance}")
            break
        else:
            print("\n..............................................\nInsuffiecient Balance to Withdraw\nPlease Enter a Valid Amount to Withdraw!")
            print(f"[Balance in your account is {balance}]\n\n❌Transaction Failed!..............................................\n")
            if attempts >= 1:
                print("Remove your card and try again later\n")    #yaha tic tic .. ... ... add karna hai abhi
                time.sleep(5)


    else:
        attempts -= 1
        print(f"🚫Transation Denied\nPlease Enter a Correct PIN!\nWarning: {attempts} attempts left with you.\n")
        if attempts >= 1:
            print("Remove your card and try again")
            print("..............................................\n..............................................\n")

        time.sleep(5)


if attempts == 0:
    print("\nYour card has been blocked!\nPlease Contact Your Branch!\n")
# Out:
# Welcome to MY BANK OF INDIA
# ATM Service Available 24x7
# Insert your card to proceed
# Enter the ATM PIN here:  2222
# 🚫Transation Denied
# Please Enter a Correct PIN!
# Warning: 2 attempts left with you.
#
# Remove your card and try again
# ..............................................
# ..............................................
# Welcome to MY BANK OF INDIA
# ATM Service Available 24x7
# Insert your card to proceed
# Enter the ATM PIN here:  4444
# 🚫Transation Denied
# Please Enter a Correct PIN!
# Warning: 1 attempts left with you.
#
# Remove your card and try again
# ..............................................
# ..............................................
# Welcome to MY BANK OF INDIA
# ATM Service Available 24x7
# Insert your card to proceed
# Enter the ATM PIN here:  44444
# 🚫Transation Denied
# Please Enter a Correct PIN!
# Warning: 0 attempts left with you.
#
#
# Your card has been blocked!
# Please Contact Your Branch!
