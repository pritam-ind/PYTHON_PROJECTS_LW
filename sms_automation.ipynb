# %%
# SMS AUTOMATION TESTING SYSTEM

# %%
from twilio.rest import Client


ACCOUNT_SID = "AC12xxxxxxxxxxxxxxxxxxx9b7d823431" 
AUTH_TOKEN = "8a9cbxxxxxxxxxxxxxxxxxxx486a89bc33" 

TWILIO_NUMBER = "+16xxxxxxxxxx45"  # virtual number by Twilio
RECEIVER_NUMBER = "+91xxxxxx9758xx" # verified phone number

client = Client(ACCOUNT_SID, AUTH_TOKEN)

try:
    message = client.messages.create(
        body="Hello! This is an automated SMS sent from Python. 🚀",
        from_=TWILIO_NUMBER,
        to=RECEIVER_NUMBER
    )
    print("SMS Sent Successfully!")
    print("Message ID:", message.sid)

except Exception as e:
    print("Error:", e)
