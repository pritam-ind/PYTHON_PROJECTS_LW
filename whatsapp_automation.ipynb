# %%
# WHATSAPP AUTOMATION

# %%
import pywhatkit as pwt

pwt.sendwhatmsg_instantly("+919801975893", "Hello sir, I'm sending this message using automation using pywhatkit and python!")
# pwt.sendwhatmsg("+919570909875", "Hello sir, I'm sending this message using automation using pywhatkit and python!", 14,06)

# pwt.sendwhatsgroupmsg_instantly("CpcanMyyHuS4C22sHskWXs", "Hello  kya haal bhai log ")
# pwt.sendwhatsgroupmsg("CpcanMyyHuS4C22sHskWXs", "Hello  kya haal bhai log  at specific time", 14, 00)
